# %%
import random
import string
import pandas as pd

# %%
pub= pd.read_csv("Datasets/Publications.csv",delimiter="|")

len(pub)
# Out:
# 3784

# %%
fl= pd.read_csv("Datasets/Reviews.csv",delimiter=",",usecols=["Text"],nrows=len(pub))
fl

pub["abstract"]=fl["Text"]

# %%
pub.to_csv("Datasets/Publications.csv",index=False,sep="|")

# %%
pub
# Out:
#                                                      id  \
# 0                           https://d-nb.info/891654135
# 1                           https://d-nb.info/880936800
# 2                           https://d-nb.info/890277257
# 3     https://d-nb.info/953963667|Fehlerquellen in r...
# 4                           https://d-nb.info/900307455
# ...                                                 ...
# 3779  http://studia.complexica.net/index.php?option=...
# 3780  http://studia.complexica.net/index.php?option=...
# 3781          https://doi.org/10.1109/MITS.2015.2439519
# 3782          https://doi.org/10.1109/MITS.2018.2879168
# 3783           https://doi.org/10.1109/MITS.2011.942201
#
#                                                   title    year  pages  \
# 0     Planspieltechnik und Computer-based-Training z...  1989.0  370.0
# 1     Informationsmanagement in der Organisationspla...  1988.0  240.0
# 2     Rechnerunterstützung für das Projektieren mit ...  1989.0  141.0
# ...
